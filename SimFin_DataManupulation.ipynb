# %%
# !pip install simfin

# %%
import simfin as sf
import pandas as pd

# %%
sf.set_api_key('e544178f-6750-4e6a-bbca-1de6df86f3a2')

# %%
sf.set_data_dir('/Users/adeenabilal/Documents/pythonCoursera/JupyterNotebook')

# %%
cashFlow_df = sf.load_cashflow(variant = 'annual', market = 'us').reset_index()
# Out:
# Dataset "us-cashflow-annual" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# Done!ding from disk ...
# /opt/anaconda3/lib/python3.13/site-packages/simfin/load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,

# %%
cashFlow_df
# Out:
#       Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 0          A  2019-10-31     45846      USD         2019            FY
# 1          A  2020-10-31     45846      USD         2020            FY
# 2          A  2021-10-31     45846      USD         2021            FY
# 3          A  2022-10-31     45846      USD         2022            FY
# 4          A  2023-10-31     45846      USD         2023            FY
# ...      ...         ...       ...      ...          ...           ...
# 17729   ZYXI  2022-12-31    171401      USD         2022            FY
# 17730   ZYXI  2023-12-31    171401      USD         2023            FY
# 17731    NaN  2021-12-31  18728220      USD         2021            FY
# 17732    NaN  2022-12-31  18728220      USD         2022            FY
# 17733    NaN  2023-12-31  18728220      USD         2023            FY
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# ...

# %%
cashFlow_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17734 entries, 0 to 17733
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Ticker                                     17731 non-null  object
#  1   Report Date                                17734 non-null  datetime64[ns]
#  2   SimFinId                                   17734 non-null  int64
#  3   Currency                                   17734 non-null  object
#  4   Fiscal Year                                17734 non-null  int64
#  5   Fiscal Period                              17734 non-null  object
#  6   Publish Date                               17734 non-null  datetime64[ns]
#  7   Restated Date                              17734 non-null  datetime64[ns]
#  8   Shares (Basic)                             17561 non-null  float64
# ...

# %%
print('Memory usage for Annual cash flow Panda Data frame is 3.8+ MB')
# Out:
# Memory usage for Annual cash flow Panda Data frame is 3.8+ MB
