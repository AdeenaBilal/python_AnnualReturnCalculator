# %%
import pandas as pd

# %%
companies_info = pd.read_csv('companies_information.csv')

# %%
#companies_info

# %%
industries_info = pd.read_csv('industries_information.csv')

# %%
#industries_info

# %%
mergedData = pd.merge(companies_info, industries_info, on = 'IndustryId', how = 'left')

# %%
#includes all the rows from the left DataFrame that have corresponding key = `industryId', in the right DataFrame to merge the data

# %%
mergedData
# Out:
#        Ticker  SimFinId                                     Company Name  \
# 0        AAON    919501                                         AAON INC
# 1        ACCO    120923                                 ACCO BRANDS Corp
# 2        ADES    619745               Advanced Emissions Solutions, Inc.
# 3        AIMC    773555                    Altra Industrial Motion Corp.
# 4        ALOT    995248                                  AstroNova, Inc.
# ...       ...       ...                                              ...
# 3117     XING    663216               China Xingbang Industry Group Inc.
# 3118  XLGROUP    903527                                     XL GROUP LTD
# 3119      XLO   1872674                         Xilio Therapeutics, Inc.
# 3120     YITD    660011  Yinhang Internet Technologies Development, Inc.
# 3121    ZINCQ    287827                           Horsehead Holding Corp
#
#       IndustryId       Sector             Industry
# ...

# %%
mergedData = pd.merge(companies_info, industries_info, on = 'IndustryId', how = 'inner')

# %%
#includes all rows that have corresponding matching key = IndustryId, in both DataFrames

# %%
mergedData
# Out:
#        Ticker  SimFinId                                     Company Name  \
# 0        AAON    919501                                         AAON INC
# 1        ACCO    120923                                 ACCO BRANDS Corp
# 2        ADES    619745               Advanced Emissions Solutions, Inc.
# 3        AIMC    773555                    Altra Industrial Motion Corp.
# 4        ALOT    995248                                  AstroNova, Inc.
# ...       ...       ...                                              ...
# 3117     XING    663216               China Xingbang Industry Group Inc.
# 3118  XLGROUP    903527                                     XL GROUP LTD
# 3119      XLO   1872674                         Xilio Therapeutics, Inc.
# 3120     YITD    660011  Yinhang Internet Technologies Development, Inc.
# 3121    ZINCQ    287827                           Horsehead Holding Corp
#
#       IndustryId       Sector             Industry
# ...

# %%
mergedData = pd.merge(companies_info, industries_info, on = 'IndustryId', how = 'outer')

# %%
#includes all the rows from each merging DataFrame and adds a NAN for missing values.

# %%
mergedData
# Out:
#        Ticker  SimFinId                                     Company Name  \
# 0        AAON    919501                                         AAON INC
# 1        ACCO    120923                                 ACCO BRANDS Corp
# 2        ADES    619745               Advanced Emissions Solutions, Inc.
# 3        AIMC    773555                    Altra Industrial Motion Corp.
# 4        ALOT    995248                                  AstroNova, Inc.
# ...       ...       ...                                              ...
# 3117     XING    663216               China Xingbang Industry Group Inc.
# 3118  XLGROUP    903527                                     XL GROUP LTD
# 3119      XLO   1872674                         Xilio Therapeutics, Inc.
# 3120     YITD    660011  Yinhang Internet Technologies Development, Inc.
# 3121    ZINCQ    287827                           Horsehead Holding Corp
#
#       IndustryId       Sector             Industry
# ...
