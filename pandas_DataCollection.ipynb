# %%
import pandas as pd

# %%
companies_info_dataset = pd.read_csv('companies_information.csv')

# %%
companies_info_dataset
# Out:
#      Ticker  SimFinId                      Company Name  IndustryId
# 0         A     45846          AGILENT TECHNOLOGIES INC    106001.0
# 1       A21   1333027                      Li Auto Inc.         NaN
# 2        AA    367153                        Alcoa Corp    110004.0
# 3       AAL     68568      American Airlines Group Inc.    100006.0
# 4      AAMC    847094  Altisource Asset Management Corp    104001.0
# ...     ...       ...                               ...         ...
# 3117    ZUO    994625                         ZUORA INC    101003.0
# 3118    ZVO    901866                         Zovio Inc    102006.0
# 3119     ZY   1243193                     Zymergen Inc.    106002.0
# 3120   ZYNE    901704     Zynerba Pharmaceuticals, Inc.    106002.0
# 3121   ZYXI    171401                         ZYNEX INC    106004.0
#
# [3122 rows x 4 columns]

# %%
pd.options.display.max_rows = 1000

# %%
companies_info_dataset.head(1000)
# Out:
#          Ticker  SimFinId                                      Company Name  \
# 0             A     45846                          AGILENT TECHNOLOGIES INC
# 1           A21   1333027                                      Li Auto Inc.
# 2            AA    367153                                        Alcoa Corp
# 3           AAL     68568                      American Airlines Group Inc.
# 4          AAMC    847094                  Altisource Asset Management Corp
# 5          AAME    450021                            ATLANTIC AMERICAN CORP
# 6           AAN    441241                             Aaron's Company, Inc.
# 7          AAOI    671827                     APPLIED OPTOELECTRONICS, INC.
# 8          AAON    919501                                          AAON INC
# 9           AAP    184955                            ADVANCE AUTO PARTS INC
# 10         AAPL    111052                                         APPLE INC
# ...

# %%
companies_info_dataset[companies_info_dataset['Company Name'] == 'APPLE INC']
# Out:
#    Ticker  SimFinId Company Name  IndustryId
# 10   AAPL    111052    APPLE INC    101001.0

# %%
print('Apple INC Ticker: 10, SimFinId: AAPL')
# Out:
# Apple INC Ticker: 10, SimFinId: AAPL
